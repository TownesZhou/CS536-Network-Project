# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

bandwidth = ["10Mbps","50Mbps","100Mbps"]
filesize = ["5KB","10KB","100KB","200KB","500KB","1MB","10MB"]

# google chrome
# score1 = np.array([[190.59,194.16,198.22,202.64,203.56,227.35,230.64],
#                   [184.36,185.46,195.62,197.73,202.86,206.91,229.93],
#                   [185.58,186.00,187.41,187.61,188.42,197.16,233.53]])


# score2 = np.array([[295.11, 293.78, 438.43, 624.89, 1152.79, 2344.55, 18412.94],
#                   [300.57, 217.79, 262.38, 304.69, 658.21, 841.85, 10747.07],
#                   [358.13, 210.74, 295.96, 345.15, 503.75, 672.36, 10218.72]])


# quic client

score1 = np.array([[35.87, 36.06, 36.90, 37.43, 38.19, 39.77, 44.17],
                  [25.50, 25.85, 25.95, 26.69, 26.85, 26.97, 28.02],
                  [21.77, 23.48, 24.87, 24.94, 24.98, 25.44, 25.71]])

score2 = np.array([[48.39,51.35,224.86,385.48,928.03,1839.83,18475.27],
                  [36.80,46.01,44.57,84.66,150.01,227.87,1908.26],
                  [32.35,60.36,65.50,92.63,107.88,177.01,1011.65]])


score = score1/score2

fig, ax = plt.subplots()
im = ax.imshow(score)

# Show all ticks and label them with the respective list entries
ax.set_xticklabels(np.arange(len(filesize)), label=filesize)
ax.set_yticklabels(np.arange(len(bandwidth)), label=bandwidth)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# plt.imshow(score, cmap='Blues', interpolation='nearest')
df = pd.DataFrame(score)
sns.heatmap(df, cmap="Greens",
            cbar_kws={"shrink": .50},
            yticklabels=bandwidth,
            xticklabels=filesize)

ax.set_title("T_QUIC/T_TCP under different Bandwidth and File Size")
plt.show()
plt.savefig('./file_size.pdf')


bandwidth = ["10Mbps","50Mbps","100Mbps"]
filesize = ["5KBx200","10KBx100","100KBx10","200KBx5","500KBx2","1MBx1"]


# google chrome
# score1 = np.array([[38118.00,19416.00,1982.20,1013.20,407.12,227.35],
#                   [36872.39,18546.88,1956.28,988.66,405.73,197.90],
#                   [37117.25,18600.55,1874.11,941.94,376.85,197.16]])


# score2 = np.array([[47633.18, 24546.95, 4040.11, 2987.18, 2449.67, 2344.55],
#                   [47753.34, 23881.60, 2947.47, 2040.10, 1117.68, 841.85],
#                   [48755.24, 24419.74, 3077.48, 1633.81, 1003.40, 672.36]])

# quic client
score1 = np.array([[6634.06, 3268.34, 312.28, 161.42, 71.12, 34.22],
                  [6534.09, 3249.91, 310.10, 157.66, 68.42, 32.25],
                  [6500.42, 3212.19, 308.66, 157.58, 66.67, 31.90]])


score2 = np.array([[9153.85, 4572.92, 2025.98, 1936.22, 1828.62, 1839.83],
                  [8197.53, 4027.28, 766.51, 479.41, 298.85, 227.87],
                  [11304.70, 5196.66, 716.51, 413.00, 191.02,177.01]])




score = score1/score2
fig, ax = plt.subplots()
im = ax.imshow(score)

# Show all ticks and label them with the respective list entries
ax.set_xticklabels(np.arange(len(filesize)), label=filesize)
ax.set_yticklabels(np.arange(len(bandwidth)), label=bandwidth)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
plt.setp(ax.get_yticklabels(), rotation=90)
# plt.yticks(rotation=0)

# plt.imshow(score, cmap='Blues', interpolation='nearest')
df = pd.DataFrame(score)
sns.heatmap(df, cmap="Greens",
            cbar_kws={"shrink": .50},
            yticklabels=bandwidth,
            xticklabels=filesize)

ax.set_title("T_QUIC/T_TCP under different Bandwidth and #Files")
plt.show()
plt.savefig('./file_number.pdf')
